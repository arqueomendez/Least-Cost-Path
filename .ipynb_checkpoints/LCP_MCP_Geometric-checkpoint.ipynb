# %%
# ==============================================================================
# --- CELDA 1: IMPORTACIONES Y MÓDULOS ---
# ==============================================================================
import os
import numpy as np
import rasterio
import fiona
from datetime import datetime
from tqdm import tqdm
import time
import gc
import glob

# --- Adiciones para Paralelización, Monitoreo y Visualización ---
import threading
import psutil
from joblib import Parallel, delayed
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm
import pandas as pd
import geopandas as gpd
import rasterio.plot
from rasterio.windows import from_bounds
from shapely.geometry import box

# --- Importar los módulos personalizados del paquete lcp ---
import lcp.data_loader as dl
import lcp.processing as proc
import lcp.pathfinder as pf
import lcp.utils as utils
import lcp.postprocessing as postp 

print("Módulos cargados exitosamente.")
# Out:
# Módulos cargados exitosamente.

# %%
# ==============================================================================
# --- CELDA 2: DEFINICIÓN DE FUNCIONES (VERSIÓN FINAL) ---
# ==============================================================================

def lcp_worker_one_to_all(args):
    """
    Worker final y definitivo para el cálculo "Uno a Todos".
    1. Calcula la superficie de coste completa desde un origen.
    2. Utiliza el método .traceback() del objeto MCP para reconstruir cada ruta.
    3. Guarda directamente los shapefiles en el disco.
    4. Devuelve solo un recuento de las rutas guardadas.
    """
    origin_id, origin_coords, all_points, shared_data = args
    
    try:
        # Cargar el ráster de coste en la memoria del worker
        cost_raster_in_memory = np.array(np.memmap(
            shared_data['memmap_path'], 
            dtype=shared_data['raster_dtype'], 
            mode='r', 
            shape=shared_data['raster_shape']
        ))
        
        # 1. Crear el objeto MCP (el grafo de costes)
        mcp = pf.create_mcp_from_cost_surface(cost_raster_in_memory)
        
        # 2. Calcular la superficie de coste desde el origen. Esta es la operación principal.
        start_pixel = proc.world_to_pixel(shared_data['src_transform'], origin_coords[0], origin_coords[1])
        mcp.find_costs([start_pixel])
        
        # 3. Iterar sobre todos los destinos, reconstruir y guardar
        saved_routes_count = 0
        for dest_id, dest_coords in all_points.items():
            if origin_id == dest_id:
                continue
            
            end_pixel = proc.world_to_pixel(shared_data['src_transform'], dest_coords[0], dest_coords[1])
            
            try:
                # Usar el método .traceback() del objeto para obtener la ruta
                path_indices, _ = mcp.traceback(end_pixel)
                
                # Convertir la lista de tuplas de índices a un array de numpy
                path_pixels = np.array(path_indices)

                # Guardar el archivo shapefile si la ruta es válida
                if path_pixels.size > 0:
                    output_path = os.path.join(shared_data['OUTPUT_DIR'], f"ruta_final_{origin_id}_a_{dest_id}.shp")
                    utils.save_path_to_shapefile(path_pixels, shared_data['src_transform'], shared_data['src_crs'], output_path)
                    saved_routes_count += 1

            except ValueError:
                # mcp.traceback() lanza un ValueError si el punto final es inalcanzable, lo ignoramos.
                continue
        
        # Liberar memoria
        del cost_raster_in_memory, mcp
        
        # Devolver solo un número, manteniendo la comunicación ligera
        return (origin_id, saved_routes_count)
    
    except Exception as e:
        print(f"ERROR en el worker para el origen {origin_id}: {e}")
        import traceback
        traceback.print_exc()
        return (origin_id, 0)

def resource_monitor(stop_event, records_list, interval=1):
    """
    Función para monitorear el uso de CPU y memoria en un hilo separado.
    """
    process = psutil.Process(os.getpid())
    while not stop_event.is_set():
        cpu = psutil.cpu_percent(interval=None)
        mem = sum(p.memory_info().rss for p in [process] + process.children(recursive=True)) / (1024 * 1024)
        records_list.append({'cpu': cpu, 'mem_mb': mem})
        time.sleep(interval)

def warm_up_numba():
    """
    Pre-compila las funciones de Numba.
    """
    # Esta función ya no es crítica para el nuevo worker, pero se mantiene por si se usa en otro lado.
    print("Ejecutando warm_up (no esencial para el worker actual)...")
    pass

# %%
# ==============================================================================
# --- CELDA 3: CONFIGURACIÓN CENTRAL DEL ANÁLISIS ---
# ==============================================================================
# --- 1. Parámetros de Rutas ---
BASE_DIR = os.getcwd()
DATA_DIR = os.path.join(BASE_DIR, 'data')
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
OUTPUT_DIR = os.path.join(BASE_DIR, 'output', f'session_{timestamp}_Refactored')

COST_RASTER_PATH = os.path.join(DATA_DIR, 'cost.tif')
ALL_POINTS_SHAPEFILE = os.path.join(DATA_DIR, 'points.shp')
MASK_SHAPEFILE_PATH = os.path.join(DATA_DIR, 'area-mask.shp')
ID_FIELD_NAME = 'id'

# --- 2. Parámetros del Algoritmo Jerárquico ---
# Elige el método de remuestreo: 'max', 'med', 'average'
RESAMPLING_METHOD_NAME = 'max'
# Factores de remuestreo. Para un ráster de ~1000x1000, valores más pequeños son mejores.
DOWNSAMPLING_FACTORS = [32, 20, 10] 
CORRIDOR_BUFFER_PIXELS = 150

# --- 3. Parámetros de A* y Paralelización ---
HEURISTIC_WEIGHT = 1.0
N_JOBS = -2

# Crear el directorio de salida inmediatamente después de definir su ruta.
# Esto asegura que estará disponible para todas las celdas posteriores (5, 6, 7).
try:
    os.makedirs(OUTPUT_DIR, exist_ok=True)
    print(f"Directorio de salida creado/verificado en: {OUTPUT_DIR}")
except OSError as e:
    print(f"!! ERROR CRÍTICO !! No se pudo crear el directorio de salida. Error: {e}")
    # Detener la ejecución si no se puede crear la carpeta
    raise

print("Parámetros de configuración cargados. Los resultados se guardarán en:", OUTPUT_DIR)
print(f"Método de remuestreo seleccionado: {RESAMPLING_METHOD_NAME.upper()}")
# Out:
# Directorio de salida creado/verificado en: G:\LCP_MCP_Geometric\output\session_20251015_223219_Refactored
# Parámetros de configuración cargados. Los resultados se guardarán en: G:\LCP_MCP_Geometric\output\session_20251015_223219_Refactored
# Método de remuestreo seleccionado: MAX

# %%
# ==============================================================================
# --- CELDA 4: VERIFICACIÓN DE COHERENCIA DE DATOS ---
# ==============================================================================
print("\n--- VERIFICANDO LA COHERENCIA DE TODOS LOS DATOS DE ENTRADA ---")

main_search_mask = None  # Inicializar la variable para que esté disponible globalmente en la celda

try:
    # --- Etapa 1: Comprobación de Sistemas de Coordenadas (CRS) ---
    print("--- Etapa 1: Comprobación de Sistemas de Coordenadas (CRS) ---")
    
    with rasterio.open(COST_RASTER_PATH) as src:
        raster_crs = src.crs
    
    with fiona.open(ALL_POINTS_SHAPEFILE) as src:
        points_crs = src.crs

    print(f"  > CRS del Ráster: {raster_crs.to_string()}")
    print(f"  > CRS de los Puntos: {fiona.crs.to_string(points_crs)}")

    crs_errors = []
    if raster_crs != points_crs:
        crs_errors.append("El CRS de los PUNTOS no coincide con el del RÁSTER.")
    
    mask_crs = None
    if MASK_SHAPEFILE_PATH and os.path.exists(MASK_SHAPEFILE_PATH):
        with fiona.open(MASK_SHAPEFILE_PATH) as src:
            mask_crs = src.crs
        print(f"  > CRS de la Máscara: {fiona.crs.to_string(mask_crs)}")
        if raster_crs != mask_crs:
            crs_errors.append("El CRS de la MÁSCARA no coincide con el del RÁSTER.")
    
    if not crs_errors:
        print("¡Correcto! Todos los sistemas de coordenadas coinciden.")
    
    # --- Etapa 2: Comprobación de Superposición Espacial ---
    print("\n--- Etapa 2: Comprobación de Superposición Espacial ---")
    
    with rasterio.open(COST_RASTER_PATH) as src:
        raster_bounds = src.bounds
        raster_box = box(*raster_bounds)

    points_gdf = gpd.read_file(ALL_POINTS_SHAPEFILE)
    points_bounds = points_gdf.total_bounds
    points_box = box(*points_bounds)
    
    print(f"  > Extensión del Ráster: {raster_bounds}")
    print(f"  > Extensión de los Puntos: {tuple(points_bounds)}")

    superposition_errors = []
    if not points_box.within(raster_box):
        superposition_errors.append("La extensión de los PUNTOS no está completamente contenida dentro de la extensión del RÁSTER.")

    if MASK_SHAPEFILE_PATH and os.path.exists(MASK_SHAPEFILE_PATH):
        mask_gdf = gpd.read_file(MASK_SHAPEFILE_PATH)
        if not mask_gdf.empty:
            mask_bounds = mask_gdf.total_bounds
            mask_box = box(*mask_bounds)
            print(f"  > Extensión de la Máscara: {tuple(mask_bounds)}")
            if not mask_box.intersects(raster_box):
                superposition_errors.append("La extensión de la MÁSCARA no se superpone (intersecta) con la extensión del RÁSTER.")
    
    if not superposition_errors:
        print("¡Correcto! Todas las capas se superponen geográficamente.")

    # --- Etapa 3: Creación y Validación Lógica de la Máscara y Puntos ---
    print("\n--- Etapa 3: Creación y Validación Lógica Final (Máscara + Nodata + Puntos) ---")
    
    with rasterio.open(COST_RASTER_PATH) as src:
        # 3.1: Crear la máscara a partir del polígono vectorial
        if MASK_SHAPEFILE_PATH and os.path.exists(MASK_SHAPEFILE_PATH):
            vector_mask = proc.create_mask_from_vector(MASK_SHAPEFILE_PATH, src)
        else:
            print("  ADVERTENCIA: No se proporcionó un archivo de máscara. Se usará toda la extensión del ráster.")
            vector_mask = np.ones(src.shape, dtype=bool)

        # 3.2: Crear una máscara a partir de los valores 'nodata' del ráster
        original_cost_data = src.read(1)
        nodata_value = src.nodata
        if nodata_value is not None:
            nodata_mask = (original_cost_data == nodata_value)
            print(f"  > Se han detectado {np.sum(nodata_mask)} píxeles con valor 'nodata' en el ráster.")
        else:
            nodata_mask = np.zeros(src.shape, dtype=bool)
        
        # 3.3: Combinar ambas para obtener la máscara de búsqueda final y definitiva
        main_search_mask = vector_mask & ~nodata_mask
        
        # 3.4: Cargar los puntos y validarlos contra la MÁSCARA FINAL
        all_points_for_validation, _ = dl.load_points_as_dict(ALL_POINTS_SHAPEFILE, ID_FIELD_NAME)
        invalid_point_ids = []
        for point_id, coords in all_points_for_validation.items():
            row, col = rasterio.transform.rowcol(src.transform, coords[0], coords[1])
            if not (0 <= row < src.height and 0 <= col < src.width) or not main_search_mask[row, col]:
                invalid_point_ids.append(str(point_id))

        if not invalid_point_ids:
            print("¡Correcto! Todos los puntos están dentro del área de búsqueda válida final.")
    
    # --- Etapa 4: Veredicto Final ---
    final_errors = crs_errors + superposition_errors
    
    if invalid_point_ids:
        error_message_points = (
            f"Se encontraron {len(invalid_point_ids)} puntos que caen sobre píxeles INVÁLIDOS. "
            f"Un píxel es inválido si está fuera del polígono de la máscara O si tiene un valor 'nodata' en el ráster de coste. "
            f"(IDs de muestra: {', '.join(invalid_point_ids[:10])}{'...' if len(invalid_point_ids) > 10 else ''})."
        )
        final_errors.append(error_message_points)

    if final_errors:
        error_details = "\n- ".join(final_errors)
        error_message = (
            f"\n{'='*70}\n"
            f"!! ERROR CRÍTICO DE VALIDACIÓN DE DATOS !!\n"
            f"Se encontraron las siguientes inconsistencias:\n- {error_details}\n\n"
            f"El análisis no puede continuar. Debes corregir tus datos de entrada. Comprueba la posición de los puntos inválidos respecto a las áreas 'nodata' en tu software GIS.\n"
            f"{'='*70}"
        )
        raise ValueError(error_message)
    else:
        print("\n¡Excelente! Todos los datos de entrada son coherentes y están listos para el análisis.")

except Exception as e:
    print(f"Ocurrió un error inesperado durante la validación de datos: {e}")
    raise
# Out:
# --- VERIFICANDO LA COHERENCIA DE TODOS LOS DATOS DE ENTRADA ---
# --- Etapa 1: Comprobación de Sistemas de Coordenadas (CRS) ---
#   > CRS del Ráster: EPSG:32719
#   > CRS de los Puntos: EPSG:32719
#   > CRS de la Máscara: EPSG:32719
# ¡Correcto! Todos los sistemas de coordenadas coinciden.
#
# --- Etapa 2: Comprobación de Superposición Espacial ---
#   > Extensión del Ráster: BoundingBox(left=296130.3322, bottom=6540316.446, right=324027.0866, top=6564143.7544)
#   > Extensión de los Puntos: (np.float64(297767.1645673349), np.float64(6543464.3754966315), np.float64(322496.8490277608), np.float64(6561182.967595575))
#   > Extensión de la Máscara: (np.float64(297210.0894099149), np.float64(6542740.155377402), np.float64(322996.8076907878), np.float64(6561733.745371203))
# ¡Correcto! Todas las capas se superponen geográficamente.
#
# --- Etapa 3: Creación y Validación Lógica Final (Máscara + Nodata + Puntos) ---
# Creando máscara booleana desde el polígono (con limpieza de geometría)...
# Máscara creada exitosamente.
#   > Se han detectado 29677 píxeles con valor 'nodata' en el ráster.
# Cargando puntos desde: points.shp
#   Usando el campo de propiedad 'id' como identificador.
# Se cargaron 14 puntos.
# ¡Correcto! Todos los puntos están dentro del área de búsqueda válida final.
#
# ¡Excelente! Todos los datos de entrada son coherentes y están listos para el análisis.

# %%
# ==============================================================================
# --- CELDA 5: VISUALIZACIÓN DIAGNÓSTICA (CON EXPORTACIÓN) ---
# ==============================================================================
print("\nIniciando visualización diagnóstica del ráster de coste y puntos...")
try:
    # Cargar el ráster de coste para obtener sus datos y metadatos
    with rasterio.open(COST_RASTER_PATH) as src:
        cost_data = src.read(1)
        transform = src.transform  # Guardar la transformación para convertir coordenadas

        # Preparar datos para la escala logarítmica, manejando valores no positivos
        min_pos_val = np.min(cost_data[cost_data > 0]) if np.any(cost_data > 0) else 1e-9
        cost_data_log = np.where(cost_data <= 0, min_pos_val, cost_data)

        # Cargar los puntos usando geopandas
        points_gdf = gpd.read_file(ALL_POINTS_SHAPEFILE)
        
        # Convertir las coordenadas geográficas de los puntos a coordenadas de píxel
        point_pixels_x = []
        point_pixels_y = []
        for point in points_gdf.geometry:
            # Usar rasterio.transform.rowcol para obtener fila y columna
            row, col = rasterio.transform.rowcol(transform, point.x, point.y)
            point_pixels_x.append(col)
            point_pixels_y.append(row)

        # Crear la figura y los ejes para los dos subplots
        fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(18, 9))

        # --- Subplot 1: Visualización con Escala Lineal ---
        im1 = ax1.imshow(cost_data, cmap='viridis')
        fig.colorbar(im1, ax=ax1, fraction=0.046, pad=0.04)
        ax1.set_title('Escala Lineal con Puntos', fontsize=16)
        ax1.scatter(point_pixels_x, point_pixels_y, c='red', edgecolor='black', s=50, label='Puntos de Análisis', zorder=5)
        ax1.legend()

        # --- Subplot 2: Visualización con Escala Logarítmica ---
        im2 = ax2.imshow(cost_data_log, cmap='viridis', norm=LogNorm())
        fig.colorbar(im2, ax=ax2, fraction=0.046, pad=0.04)
        ax2.set_title('Escala Logarítmica con Puntos', fontsize=16)
        ax2.scatter(point_pixels_x, point_pixels_y, c='red', edgecolor='black', s=50, label='Puntos de Análisis', zorder=5)
        ax2.legend()

        # Ajustes finales
        plt.tight_layout()

        # --- INICIO DE LA MODIFICACIÓN: EXPORTACIÓN DE LA IMAGEN ---
        # Guardar la figura en el directorio de salida antes de mostrarla
        output_image_path = os.path.join(OUTPUT_DIR, 'visualizacion_diagnostica.png')
        # Usamos dpi=150 para una buena resolución y bbox_inches='tight' para eliminar bordes blancos
        fig.savefig(output_image_path, dpi=150, bbox_inches='tight')
        print(f"\nVisualización diagnóstica guardada en: {output_image_path}")
        # --- FIN DE LA MODIFICACIÓN ---

        # Mostrar el gráfico en la pantalla
        plt.show()

except FileNotFoundError as e:
    print(f"ADVERTENCIA: No se encontró un archivo necesario para la visualización: {e}. Saltando visualización.")
except Exception as e:
    print(f"Ocurrió un error durante la visualización: {e}")
    import traceback
    traceback.print_exc()
# Out:
# Iniciando visualización diagnóstica del ráster de coste y puntos...
#
# Visualización diagnóstica guardada en: G:\LCP_MCP_Geometric\output\session_20251015_223219_Refactored\visualizacion_diagnostica.png

# %%
# ==============================================================================
# --- CELDA 6: EJECUCIÓN EN MODO SERIE SIMPLE (SIN MEMMAP) ---
# ==============================================================================
print("\n--- INICIANDO PROCESO DE ANÁLISIS EN MODO SERIE SIMPLE Y DIRECTO ---\n")
os.makedirs(OUTPUT_DIR, exist_ok=True)
total_routes_saved = 0

try:
    # 1. Preparar todos los datos en memoria una sola vez
    print("[Paso 1/3] Preparando todos los datos en memoria...")
    all_points, points_crs = dl.load_points_as_dict(ALL_POINTS_SHAPEFILE, ID_FIELD_NAME)
    
    with dl.load_raster(COST_RASTER_PATH) as src:
        transform = src.transform
        original_cost_data = src.read(1)
        
        # Usamos la máscara final que fue validada en la Celda 4
        # Creamos el ráster de coste final directamente en la RAM
        final_cost_raster = np.where(main_search_mask, original_cost_data, np.inf)
        
        # Liberar memoria que ya no se necesita
        del original_cost_data
    
    print(f"[Paso 1/3] Datos preparados. El ráster de coste final está en memoria (Forma: {final_cost_raster.shape}, Dtype: {final_cost_raster.dtype}).")
    
    # Calentar la función de Numba antes del bucle
    warm_up_numba()

    # 2. Ejecutar el análisis en un bucle 'for' simple y verboso
    print("\n[Paso 2/3] Iniciando bucle de procesamiento en serie...")
    start_time = time.time()
    
    # Usar tqdm para tener una barra de progreso sobre los orígenes
    for origin_id, origin_coords in tqdm(all_points.items(), desc="Procesando orígenes"):
        
        print(f"\n--- Procesando Origen ID: {origin_id} ---")
        
        try:
            # 2.1: Calcular la superficie de coste para este origen
            start_pixel = proc.world_to_pixel(transform, origin_coords[0], origin_coords[1])
            
            # Llamar a la función de cálculo con el ráster en RAM
            # La función 'cost_surface_calculator' ya es verbosa por nuestra depuración anterior
            costs_surface, traceback = pf.cost_surface_calculator(final_cost_raster, start_pixel)
            
            if traceback is None:
                print(f"  > ADVERTENCIA: El cálculo de la superficie de coste para el origen {origin_id} falló.")
                continue

            # 2.2: Extraer y guardar las rutas para este origen
            # La función 'extract_and_save_routes' también es verbosa
            saved_count = postp.extract_and_save_routes(traceback, origin_id, origin_coords, all_points, transform, points_crs, OUTPUT_DIR)
            total_routes_saved += saved_count
            
            # Liberar memoria de los resultados de esta iteración
            del costs_surface, traceback

        except Exception as e:
            print(f"!! ERROR INESPERADO procesando el origen {origin_id}: {e} !!")
            # Continuar con el siguiente origen en caso de un error aislado
            continue

    total_duration = time.time() - start_time
    print("\n[Paso 2/3] Bucle de procesamiento completado.")

    # 3. Reporte Final
    print("\n" + "="*50)
    print("--- RESUMEN DE EJECUCIÓN (MODO SERIE) ---")
    print(f"Proceso completado en {total_duration:.2f} segundos.")
    print(f"Se han guardado un total de {total_routes_saved} archivos de ruta.")
    print("="*50)

except Exception as e:
    print(f"\nOcurrió un error fatal durante la ejecución: {e}")
    import traceback
    traceback.print_exc()

finally:
    # No hay archivos temporales que limpiar en este modo
    print("\n--- ANÁLISIS COMPLETADO ---")
# Out:
# --- INICIANDO PROCESO DE ANÁLISIS EN MODO SERIE SIMPLE Y DIRECTO ---
#
# [Paso 1/3] Preparando todos los datos en memoria...
# Cargando puntos desde: points.shp
#   Usando el campo de propiedad 'id' como identificador.
# Se cargaron 14 puntos.
# Cargando raster desde: cost.tif
# [Paso 1/3] Datos preparados. El ráster de coste final está en memoria (Forma: (849, 994), Dtype: float32).
# Ejecutando warm_up (no esencial para el worker actual)...
#
# [Paso 2/3] Iniciando bucle de procesamiento en serie...
# Procesando orígenes:   0%|                                                                      | 0/14 [00:00<?, ?it/s]
# --- Procesando Origen ID: 1 ---
#
#   --- Dentro de extract_and_save_routes ---
#     > Procesando rutas desde el origen 1 (píxel (121, 58))
#       > Intentando reconstruir ruta a destino 2 (píxel (119, 260))...
# Procesando orígenes:   7%|████▍                                                         | 1/14 [00:03<00:41,  3.17s/it]
# Ruta guardada exitosamente en: ruta_final_1_a_2.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 3 (píxel (109, 514))...
# Ruta guardada exitosamente en: ruta_final_1_a_3.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 4 (píxel (105, 731))...
# Ruta guardada exitosamente en: ruta_final_1_a_4.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 5 (píxel (105, 929))...
# Ruta guardada exitosamente en: ruta_final_1_a_5.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 6 (píxel (288, 933))...
# Ruta guardada exitosamente en: ruta_final_1_a_6.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 7 (píxel (497, 935))...
# Ruta guardada exitosamente en: ruta_final_1_a_7.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 8 (píxel (730, 939))...
# Ruta guardada exitosamente en: ruta_final_1_a_8.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 9 (píxel (726, 767))...
# Ruta guardada exitosamente en: ruta_final_1_a_9.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 10 (píxel (721, 550))...
# Ruta guardada exitosamente en: ruta_final_1_a_10.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 11 (píxel (722, 279))...
# Ruta guardada exitosamente en: ruta_final_1_a_11.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 12 (píxel (736, 70))...
# Ruta guardada exitosamente en: ruta_final_1_a_12.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 13 (píxel (551, 64))...
# Ruta guardada exitosamente en: ruta_final_1_a_13.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 14 (píxel (317, 62))...
# Ruta guardada exitosamente en: ruta_final_1_a_14.shp
#         -> ÉXITO. Ruta guardada.
#
# --- Procesando Origen ID: 2 ---
# Procesando orígenes:  14%|████████▊                                                     | 2/14 [00:03<00:17,  1.49s/it]
#   --- Dentro de extract_and_save_routes ---
#     > Procesando rutas desde el origen 2 (píxel (119, 260))
#       > Intentando reconstruir ruta a destino 1 (píxel (121, 58))...
# Ruta guardada exitosamente en: ruta_final_2_a_1.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 3 (píxel (109, 514))...
# Ruta guardada exitosamente en: ruta_final_2_a_3.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 4 (píxel (105, 731))...
# Ruta guardada exitosamente en: ruta_final_2_a_4.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 5 (píxel (105, 929))...
# Ruta guardada exitosamente en: ruta_final_2_a_5.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 6 (píxel (288, 933))...
# Ruta guardada exitosamente en: ruta_final_2_a_6.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 7 (píxel (497, 935))...
# Ruta guardada exitosamente en: ruta_final_2_a_7.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 8 (píxel (730, 939))...
# Ruta guardada exitosamente en: ruta_final_2_a_8.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 9 (píxel (726, 767))...
# Ruta guardada exitosamente en: ruta_final_2_a_9.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 10 (píxel (721, 550))...
# Ruta guardada exitosamente en: ruta_final_2_a_10.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 11 (píxel (722, 279))...
# Ruta guardada exitosamente en: ruta_final_2_a_11.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 12 (píxel (736, 70))...
# Ruta guardada exitosamente en: ruta_final_2_a_12.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 13 (píxel (551, 64))...
# Ruta guardada exitosamente en: ruta_final_2_a_13.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 14 (píxel (317, 62))...
# Ruta guardada exitosamente en: ruta_final_2_a_14.shp
#         -> ÉXITO. Ruta guardada.
#
# --- Procesando Origen ID: 3 ---
# Procesando orígenes:  21%|█████████████▎                                                | 3/14 [00:03<00:10,  1.04it/s]
#   --- Dentro de extract_and_save_routes ---
#     > Procesando rutas desde el origen 3 (píxel (109, 514))
#       > Intentando reconstruir ruta a destino 1 (píxel (121, 58))...
# Ruta guardada exitosamente en: ruta_final_3_a_1.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 2 (píxel (119, 260))...
# Ruta guardada exitosamente en: ruta_final_3_a_2.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 4 (píxel (105, 731))...
# Ruta guardada exitosamente en: ruta_final_3_a_4.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 5 (píxel (105, 929))...
# Ruta guardada exitosamente en: ruta_final_3_a_5.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 6 (píxel (288, 933))...
# Ruta guardada exitosamente en: ruta_final_3_a_6.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 7 (píxel (497, 935))...
# Ruta guardada exitosamente en: ruta_final_3_a_7.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 8 (píxel (730, 939))...
# Ruta guardada exitosamente en: ruta_final_3_a_8.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 9 (píxel (726, 767))...
# Ruta guardada exitosamente en: ruta_final_3_a_9.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 10 (píxel (721, 550))...
# Ruta guardada exitosamente en: ruta_final_3_a_10.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 11 (píxel (722, 279))...
# Ruta guardada exitosamente en: ruta_final_3_a_11.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 12 (píxel (736, 70))...
# Ruta guardada exitosamente en: ruta_final_3_a_12.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 13 (píxel (551, 64))...
# Ruta guardada exitosamente en: ruta_final_3_a_13.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 14 (píxel (317, 62))...
# Ruta guardada exitosamente en: ruta_final_3_a_14.shp
#         -> ÉXITO. Ruta guardada.
#
# --- Procesando Origen ID: 4 ---
# Procesando orígenes:  29%|█████████████████▋                                            | 4/14 [00:04<00:07,  1.42it/s]
#   --- Dentro de extract_and_save_routes ---
#     > Procesando rutas desde el origen 4 (píxel (105, 731))
#       > Intentando reconstruir ruta a destino 1 (píxel (121, 58))...
# Ruta guardada exitosamente en: ruta_final_4_a_1.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 2 (píxel (119, 260))...
# Ruta guardada exitosamente en: ruta_final_4_a_2.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 3 (píxel (109, 514))...
# Ruta guardada exitosamente en: ruta_final_4_a_3.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 5 (píxel (105, 929))...
# Ruta guardada exitosamente en: ruta_final_4_a_5.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 6 (píxel (288, 933))...
# Ruta guardada exitosamente en: ruta_final_4_a_6.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 7 (píxel (497, 935))...
# Ruta guardada exitosamente en: ruta_final_4_a_7.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 8 (píxel (730, 939))...
# Ruta guardada exitosamente en: ruta_final_4_a_8.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 9 (píxel (726, 767))...
# Ruta guardada exitosamente en: ruta_final_4_a_9.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 10 (píxel (721, 550))...
# Ruta guardada exitosamente en: ruta_final_4_a_10.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 11 (píxel (722, 279))...
# Ruta guardada exitosamente en: ruta_final_4_a_11.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 12 (píxel (736, 70))...
# Ruta guardada exitosamente en: ruta_final_4_a_12.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 13 (píxel (551, 64))...
# Ruta guardada exitosamente en: ruta_final_4_a_13.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 14 (píxel (317, 62))...
# Ruta guardada exitosamente en: ruta_final_4_a_14.shp
#         -> ÉXITO. Ruta guardada.
#
# --- Procesando Origen ID: 5 ---
# Procesando orígenes:  36%|██████████████████████▏                                       | 5/14 [00:04<00:05,  1.76it/s]
#   --- Dentro de extract_and_save_routes ---
#     > Procesando rutas desde el origen 5 (píxel (105, 929))
#       > Intentando reconstruir ruta a destino 1 (píxel (121, 58))...
# Ruta guardada exitosamente en: ruta_final_5_a_1.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 2 (píxel (119, 260))...
# Ruta guardada exitosamente en: ruta_final_5_a_2.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 3 (píxel (109, 514))...
# Ruta guardada exitosamente en: ruta_final_5_a_3.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 4 (píxel (105, 731))...
# Ruta guardada exitosamente en: ruta_final_5_a_4.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 6 (píxel (288, 933))...
# Ruta guardada exitosamente en: ruta_final_5_a_6.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 7 (píxel (497, 935))...
# Ruta guardada exitosamente en: ruta_final_5_a_7.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 8 (píxel (730, 939))...
# Ruta guardada exitosamente en: ruta_final_5_a_8.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 9 (píxel (726, 767))...
# Ruta guardada exitosamente en: ruta_final_5_a_9.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 10 (píxel (721, 550))...
# Ruta guardada exitosamente en: ruta_final_5_a_10.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 11 (píxel (722, 279))...
# Ruta guardada exitosamente en: ruta_final_5_a_11.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 12 (píxel (736, 70))...
# Ruta guardada exitosamente en: ruta_final_5_a_12.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 13 (píxel (551, 64))...
# Ruta guardada exitosamente en: ruta_final_5_a_13.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 14 (píxel (317, 62))...
# Ruta guardada exitosamente en: ruta_final_5_a_14.shp
#         -> ÉXITO. Ruta guardada.
#
# --- Procesando Origen ID: 6 ---
# Procesando orígenes:  43%|██████████████████████████▌                                   | 6/14 [00:04<00:03,  2.06it/s]
#   --- Dentro de extract_and_save_routes ---
#     > Procesando rutas desde el origen 6 (píxel (288, 933))
#       > Intentando reconstruir ruta a destino 1 (píxel (121, 58))...
# Ruta guardada exitosamente en: ruta_final_6_a_1.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 2 (píxel (119, 260))...
# Ruta guardada exitosamente en: ruta_final_6_a_2.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 3 (píxel (109, 514))...
# Ruta guardada exitosamente en: ruta_final_6_a_3.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 4 (píxel (105, 731))...
# Ruta guardada exitosamente en: ruta_final_6_a_4.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 5 (píxel (105, 929))...
# Ruta guardada exitosamente en: ruta_final_6_a_5.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 7 (píxel (497, 935))...
# Ruta guardada exitosamente en: ruta_final_6_a_7.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 8 (píxel (730, 939))...
# Ruta guardada exitosamente en: ruta_final_6_a_8.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 9 (píxel (726, 767))...
# Ruta guardada exitosamente en: ruta_final_6_a_9.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 10 (píxel (721, 550))...
# Ruta guardada exitosamente en: ruta_final_6_a_10.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 11 (píxel (722, 279))...
# Ruta guardada exitosamente en: ruta_final_6_a_11.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 12 (píxel (736, 70))...
# Ruta guardada exitosamente en: ruta_final_6_a_12.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 13 (píxel (551, 64))...
# Ruta guardada exitosamente en: ruta_final_6_a_13.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 14 (píxel (317, 62))...
# Ruta guardada exitosamente en: ruta_final_6_a_14.shp
#         -> ÉXITO. Ruta guardada.
#
# --- Procesando Origen ID: 7 ---
# Procesando orígenes:  50%|███████████████████████████████                               | 7/14 [00:05<00:03,  2.31it/s]
#   --- Dentro de extract_and_save_routes ---
#     > Procesando rutas desde el origen 7 (píxel (497, 935))
#       > Intentando reconstruir ruta a destino 1 (píxel (121, 58))...
# Ruta guardada exitosamente en: ruta_final_7_a_1.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 2 (píxel (119, 260))...
# Ruta guardada exitosamente en: ruta_final_7_a_2.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 3 (píxel (109, 514))...
# Ruta guardada exitosamente en: ruta_final_7_a_3.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 4 (píxel (105, 731))...
# Ruta guardada exitosamente en: ruta_final_7_a_4.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 5 (píxel (105, 929))...
# Ruta guardada exitosamente en: ruta_final_7_a_5.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 6 (píxel (288, 933))...
# Ruta guardada exitosamente en: ruta_final_7_a_6.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 8 (píxel (730, 939))...
# Ruta guardada exitosamente en: ruta_final_7_a_8.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 9 (píxel (726, 767))...
# Ruta guardada exitosamente en: ruta_final_7_a_9.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 10 (píxel (721, 550))...
# Ruta guardada exitosamente en: ruta_final_7_a_10.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 11 (píxel (722, 279))...
# Ruta guardada exitosamente en: ruta_final_7_a_11.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 12 (píxel (736, 70))...
# Ruta guardada exitosamente en: ruta_final_7_a_12.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 13 (píxel (551, 64))...
# Ruta guardada exitosamente en: ruta_final_7_a_13.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 14 (píxel (317, 62))...
# Ruta guardada exitosamente en: ruta_final_7_a_14.shp
#         -> ÉXITO. Ruta guardada.
#
# --- Procesando Origen ID: 8 ---
# Procesando orígenes:  57%|███████████████████████████████████▍                          | 8/14 [00:05<00:02,  2.50it/s]
#   --- Dentro de extract_and_save_routes ---
#     > Procesando rutas desde el origen 8 (píxel (730, 939))
#       > Intentando reconstruir ruta a destino 1 (píxel (121, 58))...
# Ruta guardada exitosamente en: ruta_final_8_a_1.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 2 (píxel (119, 260))...
# Ruta guardada exitosamente en: ruta_final_8_a_2.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 3 (píxel (109, 514))...
# Ruta guardada exitosamente en: ruta_final_8_a_3.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 4 (píxel (105, 731))...
# Ruta guardada exitosamente en: ruta_final_8_a_4.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 5 (píxel (105, 929))...
# Ruta guardada exitosamente en: ruta_final_8_a_5.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 6 (píxel (288, 933))...
# Ruta guardada exitosamente en: ruta_final_8_a_6.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 7 (píxel (497, 935))...
# Ruta guardada exitosamente en: ruta_final_8_a_7.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 9 (píxel (726, 767))...
# Ruta guardada exitosamente en: ruta_final_8_a_9.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 10 (píxel (721, 550))...
# Ruta guardada exitosamente en: ruta_final_8_a_10.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 11 (píxel (722, 279))...
# Ruta guardada exitosamente en: ruta_final_8_a_11.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 12 (píxel (736, 70))...
# Ruta guardada exitosamente en: ruta_final_8_a_12.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 13 (píxel (551, 64))...
# Ruta guardada exitosamente en: ruta_final_8_a_13.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 14 (píxel (317, 62))...
# Ruta guardada exitosamente en: ruta_final_8_a_14.shp
#         -> ÉXITO. Ruta guardada.
#
# --- Procesando Origen ID: 9 ---
# Procesando orígenes:  64%|███████████████████████████████████████▊                      | 9/14 [00:05<00:01,  2.66it/s]
#   --- Dentro de extract_and_save_routes ---
#     > Procesando rutas desde el origen 9 (píxel (726, 767))
#       > Intentando reconstruir ruta a destino 1 (píxel (121, 58))...
# Ruta guardada exitosamente en: ruta_final_9_a_1.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 2 (píxel (119, 260))...
# Ruta guardada exitosamente en: ruta_final_9_a_2.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 3 (píxel (109, 514))...
# Ruta guardada exitosamente en: ruta_final_9_a_3.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 4 (píxel (105, 731))...
# Ruta guardada exitosamente en: ruta_final_9_a_4.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 5 (píxel (105, 929))...
# Ruta guardada exitosamente en: ruta_final_9_a_5.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 6 (píxel (288, 933))...
# Ruta guardada exitosamente en: ruta_final_9_a_6.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 7 (píxel (497, 935))...
# Ruta guardada exitosamente en: ruta_final_9_a_7.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 8 (píxel (730, 939))...
# Ruta guardada exitosamente en: ruta_final_9_a_8.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 10 (píxel (721, 550))...
# Ruta guardada exitosamente en: ruta_final_9_a_10.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 11 (píxel (722, 279))...
# Ruta guardada exitosamente en: ruta_final_9_a_11.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 12 (píxel (736, 70))...
# Ruta guardada exitosamente en: ruta_final_9_a_12.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 13 (píxel (551, 64))...
# Ruta guardada exitosamente en: ruta_final_9_a_13.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 14 (píxel (317, 62))...
# Ruta guardada exitosamente en: ruta_final_9_a_14.shp
#         -> ÉXITO. Ruta guardada.
#
# --- Procesando Origen ID: 10 ---
# Procesando orígenes:  71%|███████████████████████████████████████████▌                 | 10/14 [00:06<00:01,  2.78it/s]
#   --- Dentro de extract_and_save_routes ---
#     > Procesando rutas desde el origen 10 (píxel (721, 550))
#       > Intentando reconstruir ruta a destino 1 (píxel (121, 58))...
# Ruta guardada exitosamente en: ruta_final_10_a_1.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 2 (píxel (119, 260))...
# Ruta guardada exitosamente en: ruta_final_10_a_2.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 3 (píxel (109, 514))...
# Ruta guardada exitosamente en: ruta_final_10_a_3.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 4 (píxel (105, 731))...
# Ruta guardada exitosamente en: ruta_final_10_a_4.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 5 (píxel (105, 929))...
# Ruta guardada exitosamente en: ruta_final_10_a_5.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 6 (píxel (288, 933))...
# Ruta guardada exitosamente en: ruta_final_10_a_6.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 7 (píxel (497, 935))...
# Ruta guardada exitosamente en: ruta_final_10_a_7.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 8 (píxel (730, 939))...
# Ruta guardada exitosamente en: ruta_final_10_a_8.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 9 (píxel (726, 767))...
# Ruta guardada exitosamente en: ruta_final_10_a_9.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 11 (píxel (722, 279))...
# Ruta guardada exitosamente en: ruta_final_10_a_11.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 12 (píxel (736, 70))...
# Ruta guardada exitosamente en: ruta_final_10_a_12.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 13 (píxel (551, 64))...
# Ruta guardada exitosamente en: ruta_final_10_a_13.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 14 (píxel (317, 62))...
# Ruta guardada exitosamente en: ruta_final_10_a_14.shp
#         -> ÉXITO. Ruta guardada.
#
# --- Procesando Origen ID: 11 ---
# Procesando orígenes:  79%|███████████████████████████████████████████████▉             | 11/14 [00:06<00:01,  2.89it/s]
#   --- Dentro de extract_and_save_routes ---
#     > Procesando rutas desde el origen 11 (píxel (722, 279))
#       > Intentando reconstruir ruta a destino 1 (píxel (121, 58))...
# Ruta guardada exitosamente en: ruta_final_11_a_1.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 2 (píxel (119, 260))...
# Ruta guardada exitosamente en: ruta_final_11_a_2.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 3 (píxel (109, 514))...
# Ruta guardada exitosamente en: ruta_final_11_a_3.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 4 (píxel (105, 731))...
# Ruta guardada exitosamente en: ruta_final_11_a_4.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 5 (píxel (105, 929))...
# Ruta guardada exitosamente en: ruta_final_11_a_5.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 6 (píxel (288, 933))...
# Ruta guardada exitosamente en: ruta_final_11_a_6.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 7 (píxel (497, 935))...
# Ruta guardada exitosamente en: ruta_final_11_a_7.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 8 (píxel (730, 939))...
# Ruta guardada exitosamente en: ruta_final_11_a_8.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 9 (píxel (726, 767))...
# Ruta guardada exitosamente en: ruta_final_11_a_9.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 10 (píxel (721, 550))...
# Ruta guardada exitosamente en: ruta_final_11_a_10.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 12 (píxel (736, 70))...
# Ruta guardada exitosamente en: ruta_final_11_a_12.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 13 (píxel (551, 64))...
# Ruta guardada exitosamente en: ruta_final_11_a_13.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 14 (píxel (317, 62))...
# Ruta guardada exitosamente en: ruta_final_11_a_14.shp
#         -> ÉXITO. Ruta guardada.
#
# --- Procesando Origen ID: 12 ---
# Procesando orígenes:  86%|████████████████████████████████████████████████████▎        | 12/14 [00:06<00:00,  2.96it/s]
#   --- Dentro de extract_and_save_routes ---
#     > Procesando rutas desde el origen 12 (píxel (736, 70))
#       > Intentando reconstruir ruta a destino 1 (píxel (121, 58))...
# Ruta guardada exitosamente en: ruta_final_12_a_1.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 2 (píxel (119, 260))...
# Ruta guardada exitosamente en: ruta_final_12_a_2.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 3 (píxel (109, 514))...
# Ruta guardada exitosamente en: ruta_final_12_a_3.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 4 (píxel (105, 731))...
# Ruta guardada exitosamente en: ruta_final_12_a_4.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 5 (píxel (105, 929))...
# Ruta guardada exitosamente en: ruta_final_12_a_5.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 6 (píxel (288, 933))...
# Ruta guardada exitosamente en: ruta_final_12_a_6.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 7 (píxel (497, 935))...
# Ruta guardada exitosamente en: ruta_final_12_a_7.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 8 (píxel (730, 939))...
# Ruta guardada exitosamente en: ruta_final_12_a_8.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 9 (píxel (726, 767))...
# Ruta guardada exitosamente en: ruta_final_12_a_9.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 10 (píxel (721, 550))...
# Ruta guardada exitosamente en: ruta_final_12_a_10.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 11 (píxel (722, 279))...
# Ruta guardada exitosamente en: ruta_final_12_a_11.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 13 (píxel (551, 64))...
# Ruta guardada exitosamente en: ruta_final_12_a_13.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 14 (píxel (317, 62))...
# Ruta guardada exitosamente en: ruta_final_12_a_14.shp
#         -> ÉXITO. Ruta guardada.
#
# --- Procesando Origen ID: 13 ---
# Procesando orígenes:  93%|████████████████████████████████████████████████████████▋    | 13/14 [00:07<00:00,  3.02it/s]
#   --- Dentro de extract_and_save_routes ---
#     > Procesando rutas desde el origen 13 (píxel (551, 64))
#       > Intentando reconstruir ruta a destino 1 (píxel (121, 58))...
# Ruta guardada exitosamente en: ruta_final_13_a_1.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 2 (píxel (119, 260))...
# Ruta guardada exitosamente en: ruta_final_13_a_2.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 3 (píxel (109, 514))...
# Ruta guardada exitosamente en: ruta_final_13_a_3.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 4 (píxel (105, 731))...
# Ruta guardada exitosamente en: ruta_final_13_a_4.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 5 (píxel (105, 929))...
# Ruta guardada exitosamente en: ruta_final_13_a_5.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 6 (píxel (288, 933))...
# Ruta guardada exitosamente en: ruta_final_13_a_6.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 7 (píxel (497, 935))...
# Ruta guardada exitosamente en: ruta_final_13_a_7.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 8 (píxel (730, 939))...
# Ruta guardada exitosamente en: ruta_final_13_a_8.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 9 (píxel (726, 767))...
# Ruta guardada exitosamente en: ruta_final_13_a_9.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 10 (píxel (721, 550))...
# Ruta guardada exitosamente en: ruta_final_13_a_10.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 11 (píxel (722, 279))...
# Ruta guardada exitosamente en: ruta_final_13_a_11.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 12 (píxel (736, 70))...
# Ruta guardada exitosamente en: ruta_final_13_a_12.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 14 (píxel (317, 62))...
# Ruta guardada exitosamente en: ruta_final_13_a_14.shp
#         -> ÉXITO. Ruta guardada.
#
# --- Procesando Origen ID: 14 ---
# Procesando orígenes: 100%|█████████████████████████████████████████████████████████████| 14/14 [00:07<00:00,  1.91it/s]
#   --- Dentro de extract_and_save_routes ---
#     > Procesando rutas desde el origen 14 (píxel (317, 62))
#       > Intentando reconstruir ruta a destino 1 (píxel (121, 58))...
# Ruta guardada exitosamente en: ruta_final_14_a_1.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 2 (píxel (119, 260))...
# Ruta guardada exitosamente en: ruta_final_14_a_2.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 3 (píxel (109, 514))...
# Ruta guardada exitosamente en: ruta_final_14_a_3.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 4 (píxel (105, 731))...
# Ruta guardada exitosamente en: ruta_final_14_a_4.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 5 (píxel (105, 929))...
# Ruta guardada exitosamente en: ruta_final_14_a_5.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 6 (píxel (288, 933))...
# Ruta guardada exitosamente en: ruta_final_14_a_6.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 7 (píxel (497, 935))...
# Ruta guardada exitosamente en: ruta_final_14_a_7.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 8 (píxel (730, 939))...
# Ruta guardada exitosamente en: ruta_final_14_a_8.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 9 (píxel (726, 767))...
# Ruta guardada exitosamente en: ruta_final_14_a_9.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 10 (píxel (721, 550))...
# Ruta guardada exitosamente en: ruta_final_14_a_10.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 11 (píxel (722, 279))...
# Ruta guardada exitosamente en: ruta_final_14_a_11.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 12 (píxel (736, 70))...
# Ruta guardada exitosamente en: ruta_final_14_a_12.shp
#         -> ÉXITO. Ruta guardada.
#       > Intentando reconstruir ruta a destino 13 (píxel (551, 64))...
# Ruta guardada exitosamente en: ruta_final_14_a_13.shp
#         -> ÉXITO. Ruta guardada.
#
# [Paso 2/3] Bucle de procesamiento completado.
#
# ==================================================
# --- RESUMEN DE EJECUCIÓN (MODO SERIE) ---
# Proceso completado en 7.34 segundos.
# Se han guardado un total de 182 archivos de ruta.
# ==================================================
#
# --- ANÁLISIS COMPLETADO ---

# %%
# ==============================================================================
# --- CELDA 7: VISUALIZACIÓN Y EXPORTACIÓN FINAL DE RESULTADOS ---
# ==============================================================================
print("\nIniciando la visualización y exportación final de la red de rutas...")

try:
    # 1. Encontrar todos los archivos de ruta finales generados por el análisis
    final_route_files = glob.glob(os.path.join(OUTPUT_DIR, 'ruta_final_*.shp'))

    if not final_route_files:
        print("No se encontraron archivos de rutas finales para visualizar o exportar.")
    else:
        print(f"Se encontraron {len(final_route_files)} archivos de ruta para procesar.")
        
        # 2. Cargar todas las rutas en un único GeoDataFrame
        list_of_gdfs = [gpd.read_file(f) for f in final_route_files]
        final_routes_gdf = pd.concat(list_of_gdfs, ignore_index=True)
        
        # --- INICIO DE LA MODIFICACIÓN: EXPORTACIÓN A GEOPACKAGE ---
        # 3. Exportar el GeoDataFrame unificado a un único archivo GeoPackage
        print("\nExportando todas las rutas a un único archivo GeoPackage...")
        
        # Definir la ruta del archivo de salida
        gpkg_output_path = os.path.join(OUTPUT_DIR, 'red_completa_unificada.gpkg')
        
        # Usar el método to_file de geopandas para guardar el archivo
        # 'driver="GPKG"' especifica el formato
        # 'layer' le da un nombre a la capa dentro del archivo
        final_routes_gdf.to_file(
            gpkg_output_path,
            driver="GPKG",
            layer="rutas_unificadas"
        )
        
        print(f"Todas las rutas han sido unificadas y guardadas en: {gpkg_output_path}")
        # --- FIN DE LA MODIFICACIÓN ---

        # 4. Determinar la extensión geográfica total para la visualización
        minx, miny, maxx, maxy = final_routes_gdf.total_bounds
        margin = (maxx - minx) * 0.1
        buffered_bounds = (minx - margin, miny - margin, maxx + margin, maxy + margin)
        
        # 5. Cargar la porción del ráster de coste
        with rasterio.open(COST_RASTER_PATH) as src:
            window = from_bounds(*buffered_bounds, transform=src.transform)
            raster_data = src.read(1, window=window)
            window_transform = src.window_transform(window)

        # 6. Cargar los puntos originales
        points_gdf = gpd.read_file(ALL_POINTS_SHAPEFILE)

        # 7. Crear el mapa
        fig, ax = plt.subplots(figsize=(18, 18))
        
        # Dibujar el ráster de coste de fondo
        min_pos_val = np.min(raster_data[raster_data > 0]) if np.any(raster_data > 0) else 1e-9
        raster_data_log = np.where(raster_data <= 0, min_pos_val, raster_data)
        rasterio.plot.show(raster_data_log, transform=window_transform, ax=ax, cmap='viridis', norm=LogNorm(), alpha=0.8)
        
        # Dibujar las rutas y los nodos
        final_routes_gdf.plot(ax=ax, edgecolor='red', linewidth=0.8, label='Rutas Calculadas', alpha=0.6, zorder=3)
        points_gdf.plot(ax=ax, color='yellow', markersize=50, ec='black', label='Nodos de la Red', zorder=5)

        # 8. Configuración final del mapa
        ax.set_title('Red Completa de Rutas de Menor Costo', fontsize=20)
        ax.set_xlabel("Coordenada X"); ax.set_ylabel("Coordenada Y")
        ax.legend(); plt.grid(True, linestyle='--', alpha=0.5)
        plt.tight_layout()

        # Guardar la figura final
        output_image_path = os.path.join(OUTPUT_DIR, 'red_de_rutas_final.png')
        fig.savefig(output_image_path, dpi=300, bbox_inches='tight')
        print(f"\nVisualización final de la red guardada en: {output_image_path}")
        
        plt.show()

except Exception as e:
    print(f"Ocurrió un error durante la visualización y exportación de resultados: {e}")
    import traceback
    traceback.print_exc()
# Out:
# Iniciando la visualización y exportación final de la red de rutas...
# Se encontraron 182 archivos de ruta para procesar.
#
# Exportando todas las rutas a un único archivo GeoPackage...
# Todas las rutas han sido unificadas y guardadas en: G:\LCP_MCP_Geometric\output\session_20251015_223219_Refactored\red_completa_unificada.gpkg
#
# Visualización final de la red guardada en: G:\LCP_MCP_Geometric\output\session_20251015_223219_Refactored\red_de_rutas_final.png
